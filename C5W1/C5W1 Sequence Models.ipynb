# %% [markdown]
# ## Recurrent Neural Network : 왜 순차적(Sequence) 모델?
# <img src="./images/C5W1.01.png" width="700">
# <hr>
#
# ### RNN : 표기(Notation) : 동기부여 예
#
# #### X :  $\quad \quad$ Harry Potter and Hermione Granger invented a new spell.
# <br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br>
# <hr>
#
# ### 표기(Notation) : 단어 표현
#
# #### X :  $\quad $  Harry &nbsp; Potter  &nbsp; and  &nbsp;Hermione  &nbsp;Granger invented &nbsp; a &nbsp; new &nbsp; spell.
# $\quad \quad x^{<1>}\quad x^{<2>} \quad x^{<3>} \quad\quad\quad\quad\quad\quad \cdots \quad\quad\quad\quad\quad\quad \quad x^{<9>} \quad $
#
# <br><br>
# <br><br><br><br><br><br><br><br><br><br>
# <hr>
#
# ### 표기(Notation) : 단어 표현
#
# #### X :  $\quad $  Harry &nbsp; Potter  &nbsp; and  &nbsp;Hermione  &nbsp;Granger invented &nbsp; a &nbsp; new &nbsp; spell.
# $\quad \quad x^{<1>}\quad x^{<2>} \quad x^{<3>} \quad\quad\quad\quad\quad\quad \cdots \quad\quad\quad\quad\quad x^{<9>} \quad $
#
# <br>
# <pre>
# And = 367
# Invented = 4700
# A = 1
# New = 5976
# Spell = 8376
# Harry = 4075
# Potter = 6830
# Hermione = 4200
# Gran… = 4000
# </pre>
# <hr>

# %% [markdown]
# ## 순환신경망 RNN 모델 : 왜 표준 신경망은 안되는가?
# <br>
# <img src="./images/C5W1.02.png" width="700">
# <br>
#
# **문제점**
# * 입력, 출력은 다른 예에서 길이가 다를 수 있습니다.
# * 다양한 텍스트 위치에서 학습된 특징을 공유하지 않습니다.
# <br>
# <br>
# <hr>
#
# ## 순환신경망 RNN
# <br><br><br><br><br><br><br><br><br><br><br><br>
# He said, “Teddy Roosevelt was a great President.”
# <br>
# He said, “Teddy bears are on sale!”
# <br>
# <hr>
#
# ## 순방향전파(Forward Propagation)
# <br>
# <img src="./images/C5W1.03.png" width="700">
# <br>
# <br>
# <br><br><br><br>
# <hr>
#
# ## 단순화된 RNN 표기
# <br><br>
# $ a^{<t>} = g(W_{aa}a^{<t-1>} + W_{ax}x^{<t>} + b_a) $
# <br><br><br>
# $ \hat{y}^{<t>} = g(W_{ya}a^{<t>} +  b_y) $
# <br>
# <br>
# <br>
# <br><br><br><br><br><br>
# <br>
# <br>
# <hr>

# %% [markdown]
# ## 시간으로 역전파 : 순전파와 역전파
# <br>
# <img src="./images/C5W1.04.png" width="700">
# <br>
# <br>
# <br><br>
# <br>
# <hr>
#
# ## 순전파와 역전파
# <br>
# <br>
# <br>
# <br><br><br><br><br><br>
# <br>
# <br>
# <br><br>
# $\mathscr{L}^{<t>}(\hat{y}^{<t>},y^{<t>})$
# <br>
# <br>
# <br>
# <hr>

# %% [markdown]
# ## RNN의 여러 타입들
# <img src="./images/C5W1.01.png" width="700">
# <hr>
#
# ## RNN 구조의 예
# <br>
# <br>
# <br>
# <br><br>
# <br><br>
# <br><br><br><br>
# <br><br><br><br>
#
# <br>
# <hr>
#
# ## RNN 구조의 예
# <br>
# <br>
# <br>
# <br><br>
# <br><br>
# <br><br><br><br>
# <br><br><br><br>
# <br>
# <hr>
#
# ## RNN 타입들의 예
# <br>
# <img src="./images/C5W1.05.png" width="700">
# <br>
# <hr>

# %% [markdown]
# ## 언어 모델과 시퀀스 생성 : 언어 모델링이란 무엇인가?
#
# **음성 인식 예**
# <pre>
#      The apple and pair salad.
#
#      The apple and pear salad.
#
#      P(The apple and pair salad) =
#
#      P(The apple and pear salad) =
# </pre>
# <br><br><br><br><br><br>
# <hr>
#
# ## RNN 으로 언어 모델링
#
# ### 훈련 자료: 영어문장의 큰 말뭉치(corpus)
#
# <br><br>
#
# ### Cats average 15 hours of sleep a day.
#
# <br><br>
#
# ### The Egyptian Mau is a bread of cat.  &lt;EOS&gt;
#
# <br><br><br>
# <hr>
#
# ## RNN  모델링
#
# <br><br><br><br><br><br><br><br><br>
#
# Cats average 15 hours of sleep a day. &lt;EOS&gt;
#
# $ \mathscr{L}^{<t>}(\hat{y}^{<t>},y^{<t>}) = -\sum_t y_t^{<t>} \log \hat{y}_t^{<t>}$
#
# $ \mathscr{L} =\sum_t \mathscr{L}^{<t>}(\hat{y}^{<t>},y^{<t>})$
#
# <hr>

# %% [markdown]
# ### 소설 시퀀스 샘플링
# ### 훈련된 RNN 으로부터 하나의 시퀀스 샘플링하기
#
# <img src="./images/C5W1.06.png" width="700">
# <br><br><br><br><br><br><br><br>
# <hr>
#
# ## 문자 수준의 언어 모델
# <img src="./images/C5W1.07.png" width="700">
# <br>
# <hr>
#
# ### 시퀀스 생성
#
# <br>
# <br>
# <table>
#     <tr>
#         <td width="40%" style="text-align:center">News</td>
#         <td width="40%" style="text-align:center"> Shakespeare</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">
#             President enrique peña nieto, announced sench’s sulk former coming football langston paring.
# <br><br>
# “I was not at all surprised,” said hich langston.
#
# “Concussion epidemic”, to be examined.
#
# The gray football the told some and this has on the uefa icon, should money as.
#         </td>
#         <td style="text-align:left">
#             The mortal moon hath her eclipse in love.
#  <br><br>
# And subject of this thou art another this fold.
#
# When besser be my love to me see sabl’s.
#
# For whose are ruse of mine eyes heaves.
#         </td>
#     </tr>
# </table>
#
# <br>
# <br>
# <br>
# <br>
# <hr>

# %% [markdown]
# ## RNN에서의 그래디언트 소멸
# <br>
# <img src="./images/C5W1.08.png" width="700">
# <br><br>
# <hr>

# %% [markdown]
# ### Gated Recurrent Unit (GRU)
# ### RNN unit
# <br><br><br><br><br><br>
# $$ a^{<t>} = g(W_a [a^{<t-1>}, x^{<t>} ] + b_a)$$
# <br><br><br><br><br><br>
# <hr>
#
# ### (단순화된) GRU
# <br><br><br><br>
# <br><br><br><br>
# <br><br><br><br><br><br><br>
# The cat, which already ate ..., was full.
# <br>
# <hr>
#
#
# ### 전체 GRU
# <br><br><br>
# $ \tilde{c}^{<t>} = tanh(W_c [ \quad\quad c^{<t-1>}, x^{<t>} ] + b_c)$
# <br><br><br>
# $ \Gamma_u = \sigma(W_u [c^{<t-1>}, x^{<t>} ] + b_u)$
# <br><br><br><br>
# $ c^{<t>} = \Gamma_u\tilde{c}^{<t>} + (1 - \Gamma_u) *  c^{<t-1>}$
# <br><br><br>
# The cat, which already ate ..., was full.
# <br>
# <hr>

# %% [markdown]
# ### LSTM (long short-term memory) unit
#
# <br><br>
#
# <table>
#     <tr>
#         <td width="50%"  style="text-align:center">GRU</td><td width="50%" style="text-align:center">LSTM</td>
#     </tr>
#     <tr>
#         <td>
#          $$\tilde{c}^{<t>} = \tanh ( W_c [\Gamma_r *c^{<t-1>}, x^{<t>} ] + b_c)$$
#          <br><br>
#          $$\Gamma_u = \sigma( W_u [c^{<t-1>}, x^{<t>} ] + b_u)$$
#          <br><br>
#          $$ \Gamma_r = \sigma( W_r [c^{<t-1>}, x^{<t>} ] + b_r)$$
#          <br><br>
#             $$ c^{<t>} = \Gamma_u\tilde{c}^{<t>} + (1 - \Gamma_u) *  c^{<t-1>}$$
#             <br>
#             $$ a^{<t>} = c^{<t>}$$
#         </td>
#         <td>
#         </td>
#     </tr>
# </table>
#
# <br><br><br>
# <hr>
#
# ### LSTM (long short-term memory) unit
#
# <br>
# <table>
#     <tr>
#         <td width="50%"  style="text-align:center">GRU</td><td width="50%" style="text-align:center">LSTM</td>
#     </tr>
#     <tr>
#         <td>
#          $$\tilde{c}^{<t>} = \tanh(W_c [\Gamma_r * c^{<t-1>}, x^{<t>} ] + b_c)$$
#          <br><br>
#          $$\Gamma_u = \sigma(W_u [c^{<t-1>}, x^{<t>} ] + b_u)$$
#             <br><br>
#          $$ \Gamma_r = \sigma(W_r [c^{<t-1>}, x^{<t>} ] + b_r)$$
#             <br><br>
#             $$ c^{<t>} = \Gamma_u\tilde{c}^{<t>} + (1 - \Gamma_u) *  c^{<t-1>}$$
#             <br><br>
#             $$ a^{<t>} = c^{<t>}$$
#             <br><br><br>
#         </td>
#         <td>
# $$\tilde{c}^{<t>} = \tanh(W_c [c^{<t-1>}, x^{<t>} ] + b_c)$$
#          <br><br>
#          $$\Gamma_u = \sigma(W_u [c^{<t-1>}, x^{<t>} ] + b_u)$$
#             <br><br>
#          $$ \Gamma_f = \sigma(W_f [c^{<t-1>}, x^{<t>} ] + b_f)$$
#             <br><br>
#          $$ \Gamma_o = \sigma(W_o [a^{<t-1>}, x^{<t>} ] + b_o)$$
#             <br><br>
#             $$ c^{<t>} = \Gamma_u * \tilde{c}^{<t>} + \Gamma_f *  c^{<t-1>}$$
#             <br><br>
#             $$ a^{<t>} = \Gamma_o *c^{<t>}$$
#         </td>
#     </tr>
# </table>
#
# <br>
# <hr>
#
# ### 그림으로 본 LSTM
#
# <img src="./images/C5W1.09.png" width="700">
# <br>
# <hr>

# %% [markdown]
# ### Bidirectional RNN
#
# #### 미래로부터 정보를 얻기
#
# He said, "Teddy bears are on sale!"
# <br>
# He said, "Teddy Roosevelt was a great President!"
# <br>
# <img src="./images/C5W1.10.png" width="700">
# <br>
# <hr>
#
# ### BRNN (Bidirectional RNN)
# <br><br><br><br>
# <br><br><br><br>
# <br><br><br><br><br><br>
#
# <hr>

# %% [markdown]
# ### Deep RNN : example
#
# <br><br>
# <img src="./images/C5W1.11.png" width="700">
# <br><br><br>
# <hr>
